# %% [markdown]
# ## 문제
# 정수 n을 입력하고 n까지의 짝수의 합
#
# ---
#
# ## 입력
#
# 1<=n<=10000
#
# ---
#
# ## 출력
# ---
# n
# ---

# %%
n = input()
# Out:
# 60

# %%
s_list=[i for i in range(int(n)+1)if i % 2 == 0]

total = sum(s_list)
print(total)
# Out:
# 930
